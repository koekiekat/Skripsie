# %%
from pathlib import Path
from selection import load_file_calls_with_labels, classify_calls_from_labels
from temp_selection import review_calls_with_labels

DATA_29 = Path(r"C:\Users\HP\Desktop\Skripsie data\29")
RESULTS_29 = DATA_29 / "template_selections"
RESULTS_29.mkdir(exist_ok=True)

DATA_26 = Path(r"C:\Users\HP\Desktop\Skripsie data\26")
RESULTS_26 = DATA_26 / "template_selections"
RESULTS_26.mkdir(exist_ok=True)

DATA_22 = Path(r"C:\Users\HP\Desktop\Skripsie data\22")
RESULTS_22 = DATA_22 / "template_selections"
RESULTS_22.mkdir(exist_ok=True)

# %% [markdown]
# 29

# %%
# Recording: 20230429_102841
f_s, x, start_t, end_t, segments, labels = load_file_calls_with_labels(
    DATA_29 / "20230429_102841.WAV",
    DATA_29 / "2023-04-29T10-28-41_000_00074.txt"
)

# %%
classify_calls_from_labels(
    labels,
    file_label="20230429_Labels",
    recording_label="20230429_102841",
    results_dir=RESULTS_29
)

# %%
review_calls_with_labels(segments, f_s, start_t, labels, "20230429")

# %% [markdown]
# 26

# %%
f_s, x, start_t, end_t, segments, labels = load_file_calls_with_labels(
    DATA_26 / "20230426_075505.WAV",
    DATA_26 / "2023-04-26T07-55-05_000_00072.txt"
)

# %%
classify_calls_from_labels(
    labels,
    file_label="20230426_Labels",
    recording_label="20230426_075505",
    results_dir=RESULTS_26
)

# %% [markdown]
# 22

# %%
f_s, x, start_t, end_t, segments, labels = load_file_calls_with_labels(
    DATA_22 / "20230422_171301.WAV",
    DATA_22 / "2023-04-22T17-13-01_000_00070.txt"
)

# %%
review_calls_with_labels(segments, f_s, start_t, labels, "20230429")

# %%
classify_calls_from_labels(
    labels,
    file_label="20230422_Labels",
    recording_label="20230422_171301",
    results_dir=RESULTS_22
)
