# %%
from pathlib import Path
from temp_selection import load_file_calls_with_labels, select_templates_interactive

DATA_29 = Path(r"C:\Users\HP\Desktop\Skripsie data\29")
RESULTS_29 = DATA_29 / "template_selections"
RESULTS_29.mkdir(exist_ok=True)

# %%
f_s, x, start_t, end_t, segments, labels = load_file_calls_with_labels(
    DATA_29 / "20230429_102841.WAV",
    DATA_29 / "2023-04-29T10-28-41_000_00074.txt"
)

# %% [markdown]
# single-tones

# %%
select_templates_interactive(
    wav_path=DATA_29 / "20230429_102841.WAV",
    segments=segments, f_s=f_s, start_t=start_t, end_t=end_t, labels=labels,
    call_type="single_tone",
    n_templates=10,
    file_label="20230429_Templates",
    recording_label="20230429_102841",
    results_dir=RESULTS_29,
)
# Out:
# Already have 10 template(s) for 'single_tone' in 20230429_Templates/20230429_102841 (target 10). Nothing to do.
# [{'index': 1,
#   'call_type': 'single_tone',
#   'start_time': 551.1319374999999,
#   'end_time': 551.4919375000001,
#   'wav_path': 'C:\\Users\\HP\\Desktop\\Skripsie data\\29\\20230429_102841.WAV'},
#  {'index': 4,
#   'call_type': 'single_tone',
#   'start_time': 2126.6519375000003,
#   'end_time': 2126.9479375,
#   'wav_path': 'C:\\Users\\HP\\Desktop\\Skripsie data\\29\\20230429_102841.WAV'},
#  {'index': 9,
#   'call_type': 'single_tone',
#   'start_time': 15577.5319375,
#   'end_time': 15577.8919375,
#   'wav_path': 'C:\\Users\\HP\\Desktop\\Skripsie data\\29\\20230429_102841.WAV'},
#  {'index': 11,
#   'call_type': 'single_tone',
#   'start_time': 15683.9319375,
#   'end_time': 15684.3559375,
#   'wav_path': 'C:\\Users\\HP\\Desktop\\Skripsie data\\29\\20230429_102841.WAV'},
#  {'index': 12,
#   'call_type': 'single_tone',
#   'start_time': 15721.3079375,
#   'end_time': 15721.6999375,
#   'wav_path': 'C:\\Users\\HP\\Desktop\\Skripsie data\\29\\20230429_102841.WAV'},
#  {'index': 5,
#   'call_type': 'single_tone',
#   'start_time': 4390.5879374999995,
#   'end_time': 4391.0119375,
#   'wav_path': 'C:\\Users\\HP\\Desktop\\Skripsie data\\29\\20230429_102841.WAV'},
#  {'index': 6,
#   'call_type': 'single_tone',
#   'start_time': 4852.667937499999,
#   'end_time': 4852.995937500001,
#   'wav_path': 'C:\\Users\\HP\\Desktop\\Skripsie data\\29\\20230429_102841.WAV'},
#  {'index': 7,
#   'call_type': 'single_tone',
#   'start_time': 15437.3079375,
#   'end_time': 15437.635937500001,
#   'wav_path': 'C:\\Users\\HP\\Desktop\\Skripsie data\\29\\20230429_102841.WAV'},
#  {'index': 10,
#   'call_type': 'single_tone',
#   'start_time': 15657.6279375,
#   'end_time': 15657.9559375,
#   'wav_path': 'C:\\Users\\HP\\Desktop\\Skripsie data\\29\\20230429_102841.WAV'},
#  {'index': 15,
#   'call_type': 'single_tone',
#   'start_time': 15917.115937499999,
#   'end_time': 15917.4439375,
#   'wav_path': 'C:\\Users\\HP\\Desktop\\Skripsie data\\29\\20230429_102841.WAV'}]

# %% [markdown]
# multi-tones

# %%
select_templates_interactive(
    wav_path=DATA_29 / "20230429_102841.WAV",
    segments=segments, f_s=f_s, start_t=start_t, end_t=end_t, labels=labels,
    call_type="multi_tone",
    n_templates=10,
    file_label="20230429_Templates",
    recording_label="20230429_102841",
    results_dir=RESULTS_29,
)
# Out:
# Already have 10 template(s) for 'multi_tone' in 20230429_Templates/20230429_102841 (target 10). Nothing to do.
# [{'index': 17,
#   'call_type': 'multi_tone',
#   'start_time': 39403.6119375,
#   'end_time': 39404.067937499996,
#   'wav_path': 'C:\\Users\\HP\\Desktop\\Skripsie data\\29\\20230429_102841.WAV'},
#  {'index': 20,
#   'call_type': 'multi_tone',
#   'start_time': 44860.4439375,
#   'end_time': 44860.8039375,
#   'wav_path': 'C:\\Users\\HP\\Desktop\\Skripsie data\\29\\20230429_102841.WAV'},
#  {'index': 21,
#   'call_type': 'multi_tone',
#   'start_time': 44874.4599375,
#   'end_time': 44874.851937499996,
#   'wav_path': 'C:\\Users\\HP\\Desktop\\Skripsie data\\29\\20230429_102841.WAV'},
#  {'index': 30,
#   'call_type': 'multi_tone',
#   'start_time': 47487.963937500004,
#   'end_time': 47488.3559375,
#   'wav_path': 'C:\\Users\\HP\\Desktop\\Skripsie data\\29\\20230429_102841.WAV'},
#  {'index': 32,
#   'call_type': 'multi_tone',
#   'start_time': 52301.0199375,
#   'end_time': 52301.4759375,
#   'wav_path': 'C:\\Users\\HP\\Desktop\\Skripsie data\\29\\20230429_102841.WAV'},
#  {'index': 19,
#   'call_type': 'multi_tone',
#   'start_time': 44788.4119375,
#   'end_time': 44788.9319375,
#   'wav_path': 'C:\\Users\\HP\\Desktop\\Skripsie data\\29\\20230429_102841.WAV'},
#  {'index': 22,
#   'call_type': 'multi_tone',
#   'start_time': 44876.1239375,
#   'end_time': 44876.4519375,
#   'wav_path': 'C:\\Users\\HP\\Desktop\\Skripsie data\\29\\20230429_102841.WAV'},
#  {'index': 24,
#   'call_type': 'multi_tone',
#   'start_time': 45950.0759375,
#   'end_time': 45950.563937499996,
#   'wav_path': 'C:\\Users\\HP\\Desktop\\Skripsie data\\29\\20230429_102841.WAV'},
#  {'index': 28,
#   'call_type': 'multi_tone',
#   'start_time': 46891.9959375,
#   'end_time': 46892.387937499996,
#   'wav_path': 'C:\\Users\\HP\\Desktop\\Skripsie data\\29\\20230429_102841.WAV'},
#  {'index': 29,
#   'call_type': 'multi_tone',
#   'start_time': 46955.963937500004,
#   'end_time': 46956.3559375,
#   'wav_path': 'C:\\Users\\HP\\Desktop\\Skripsie data\\29\\20230429_102841.WAV'}]

# %% [markdown]
# burst-tonals

# %%
select_templates_interactive(
    wav_path=DATA_29 / "20230429_102841.WAV",
    segments=segments, f_s=f_s, start_t=start_t, end_t=end_t, labels=labels,
    call_type="burst_tonal",
    n_templates=10,
    file_label="20230429_Templates",
    recording_label="20230429_102841",
    results_dir=RESULTS_29,
)
# Out:
# Already have 10 template(s) for 'burst_tonal' in 20230429_Templates/20230429_102841 (target 10). Nothing to do.
# [{'index': 3,
#   'call_type': 'burst_tonal',
#   'start_time': 1502.0759375,
#   'end_time': 1502.5639374999998,
#   'wav_path': 'C:\\Users\\HP\\Desktop\\Skripsie data\\29\\20230429_102841.WAV'},
#  {'index': 14,
#   'call_type': 'burst_tonal',
#   'start_time': 15813.723937499999,
#   'end_time': 15814.243937500001,
#   'wav_path': 'C:\\Users\\HP\\Desktop\\Skripsie data\\29\\20230429_102841.WAV'},
#  {'index': 38,
#   'call_type': 'burst_tonal',
#   'start_time': 89893.1799375,
#   'end_time': 89893.53993750001,
#   'wav_path': 'C:\\Users\\HP\\Desktop\\Skripsie data\\29\\20230429_102841.WAV'},
#  {'index': 39,
#   'call_type': 'burst_tonal',
#   'start_time': 89926.49193749999,
#   'end_time': 89927.2039375,
#   'wav_path': 'C:\\Users\\HP\\Desktop\\Skripsie data\\29\\20230429_102841.WAV'},
#  {'index': 46,
#   'call_type': 'burst_tonal',
#   'start_time': 104091.35593749999,
#   'end_time': 104091.7799375,
#   'wav_path': 'C:\\Users\\HP\\Desktop\\Skripsie data\\29\\20230429_102841.WAV'},
#  {'index': 42,
#   'call_type': 'burst_tonal',
#   'start_time': 94086.42793749999,
#   'end_time': 94086.81993750001,
#   'wav_path': 'C:\\Users\\HP\\Desktop\\Skripsie data\\29\\20230429_102841.WAV'},
#  {'index': 43,
#   'call_type': 'burst_tonal',
#   'start_time': 99038.93993749999,
#   'end_time': 99039.5559375,
#   'wav_path': 'C:\\Users\\HP\\Desktop\\Skripsie data\\29\\20230429_102841.WAV'},
#  {'index': 45,
#   'call_type': 'burst_tonal',
#   'start_time': 104076.8279375,
#   'end_time': 104077.1239375,
#   'wav_path': 'C:\\Users\\HP\\Desktop\\Skripsie data\\29\\20230429_102841.WAV'},
#  {'index': 48,
#   'call_type': 'burst_tonal',
#   'start_time': 104241.0199375,
#   'end_time': 104241.4119375,
#   'wav_path': 'C:\\Users\\HP\\Desktop\\Skripsie data\\29\\20230429_102841.WAV'},
#  {'index': 49,
#   'call_type': 'burst_tonal',
#   'start_time': 104312.21993749999,
#   'end_time': 104312.73993750001,
#   'wav_path': 'C:\\Users\\HP\\Desktop\\Skripsie data\\29\\20230429_102841.WAV'}]
