# %%
from pathlib import Path
from test_vectorized import read_audio_chunk, plot_pr_curve, load_threshold, load_template_segment, batch_stft_windows, dtw_costs_vectorized, load_raven_selection_table, compute_pr_curve, compute_average_precision, match_detections
from stft import plot_spectrogram
import json
import numpy as np


DATA_22 = Path(r"C:\Users\HP\Desktop\Skripsie data\22")
DATA_29 = Path(r"C:\Users\HP\Desktop\Skripsie data\29")
RESULTS_29 = DATA_29 / "template_selections"

# %%
st_temps = RESULTS_29 / "20230429_Templates_20230429_102841_single_tone_templates.json"
mt_temps = RESULTS_29 / "20230429_Templates_20230429_102841_multi_tone_templates.json"
bt_temps = RESULTS_29 / "20230429_Templates_20230429_102841_burst_tonal_templates.json"

#load template data from .json file
with open(st_temps) as f:
    st_templates = json.load(f)

with open(mt_temps) as f:
    mt_templates = json.load(f)

with open(bt_temps) as f:
    bt_templates = json.load(f)

st_templates = st_templates[:10]
mt_templates = mt_templates[:10]
bt_templates = bt_templates[:10]

st_stfts = [load_template_segment(t, 1000) for t in st_templates]
mt_stfts = [load_template_segment(t, 1000) for t in mt_templates]
bt_stfts = [load_template_segment(t, 1000) for t in bt_templates]

# %% [markdown]
# Load thresholds

# %%
st = load_threshold(file_label = "20230429_Templates", 
               call_type = "single_tone", 
               results_dir = RESULTS_29)

st_threshold = st["threshold"]

mt = load_threshold(file_label = "20230429_Templates", 
               call_type = "multi_tone", 
               results_dir = RESULTS_29)

mt_threshold = mt["threshold"]

bt = load_threshold(file_label = "20230429_Templates", 
               call_type = "burst_tonal", 
               results_dir = RESULTS_29)

bt_threshold = bt["threshold"]

print(f"Single Tone Threshold: {st_threshold}")
print(f"Multi Tone Threshold: {mt_threshold}")
print(f"Burst Tonal Threshold: {bt_threshold}")
# Out:
# Single Tone Threshold: 0.15584550567097
# Multi Tone Threshold: 0.14579832187276143
# Burst Tonal Threshold: 0.15287005563825773

# %% [markdown]
# Load 72 hour audio in 1 hour segments

# %%
all_detected_t = []       # global list, accumulates across all hours
all_detected_labels = []  # optional: keep track of call type too
all_scores = []      # NEW: raw mean_cost for every window, every hour
all_labels_all = []  # NEW: best-matching call type for every window (even if not triggered)
all_times_all = []   # NEW: global time for every window

for i in range(72):
    #print(f"Processing hour {i+1} of 72")
    #load 1 hour of audio and resample to fs = 1000Hz
    f_s, audio_array = read_audio_chunk(DATA_22 / "20230422_171301.wav", i, duration_hour=1.0, fs_new=1000)

    #split audio into windows and store in a vector and calculate STFT for each window
    f_win, t_win,Zxx_window = batch_stft_windows(audio_array, 
                                                window_len = int(0.15*1000), 
                                                step_len = int(0.15*1000/2), 
                                                fs_new = f_s, 
                                                framelength = int(f_s * 0.128), 
                                                noverlap = int(int(f_s * 0.128) * 0.75))

    costs_st, costs_mt, costs_bt = dtw_costs_vectorized(st_stfts, 
                                                    mt_stfts, 
                                                    bt_stfts, 
                                                    n_templates = 10, 
                                                    audio_segment = Zxx_window)  

    '''n_windows = Zxx_window.shape[0]
    call_detected = np.zeros(n_windows, dtype=bool)
    call_labels = np.full(n_windows, "", dtype=object)

    for costs_list, threshold, label in [(costs_st, st_threshold, "st"),
                                        (costs_mt, mt_threshold, "mt"),
                                        (costs_bt, bt_threshold, "bt")]:
        costs_arr = np.vstack(costs_list)        # shape: (n_templates, n_windows)
        below_thresh = costs_arr < threshold     # shape: (n_templates, n_windows)
        triggered = below_thresh.any(axis=0)     # shape: (n_windows,) -- True if ANY template hit

        # only tag windows that haven't already been tagged by an earlier call type
        newly_triggered = triggered & ~call_detected
        call_labels[newly_triggered] = label
        call_detected |= triggered'''
    # compute votes/mean_cost for all three call types first, then decide winner per window
    results = {}
    for costs_list, threshold, label in [(costs_st, st_threshold, "st"),
                                        (costs_mt, mt_threshold, "mt"),
                                        (costs_bt, bt_threshold, "bt")]:

        costs_arr = np.vstack(costs_list)
        n_templates = costs_arr.shape[0]
        votes = (costs_arr < threshold).sum(axis=0)
        mean_cost = costs_arr.mean(axis=0)
        triggered = votes >= np.ceil(0.6 * n_templates)
        results[label] = (triggered, mean_cost)

    n_windows = Zxx_window.shape[0]
    call_detected = np.zeros(n_windows, dtype=bool)
    call_labels = np.full(n_windows, "", dtype=object)
    best_cost = np.full(n_windows, np.inf)
    best_cost_all = np.full(n_windows, np.inf)
    best_label_all = np.full(n_windows, "", dtype=object)

    for label, (triggered, mean_cost) in results.items():
        all_time_better = mean_cost < best_cost_all
        best_label_all[all_time_better] = label
        best_cost_all[all_time_better] = mean_cost[all_time_better]

        triggered_better = triggered & (mean_cost < best_cost)
        call_labels[triggered_better] = label
        best_cost[triggered_better] = mean_cost[triggered_better]
        call_detected |= triggered

    print(f"Processing hour {i+1} of 72: {call_detected.sum()} / {n_windows} windows flagged as calls")

    window_times_global = np.arange(n_windows) * 0.075 + i * 3600
    all_scores.extend(best_cost_all.tolist())
    all_labels_all.extend(best_label_all.tolist())
    all_times_all.extend(window_times_global.tolist())

    detected = np.where(call_detected)[0]
    detected_t = detected*75/1000
    detected_t_global = detected_t + i*3600
    all_detected_t.extend(detected_t_global.tolist())
    all_detected_labels.extend(call_labels[detected].tolist())

# after the loop, convert to arrays for downstream use
all_detected_t = np.array(all_detected_t)
all_detected_labels = np.array(all_detected_labels, dtype=object)
all_scores = np.array(all_scores)
all_labels_all = np.array(all_labels_all, dtype=object)
all_times_all = np.array(all_times_all)
# Out:
# Processing hour 1 of 72: 40 / 47999 windows flagged as calls
# Processing hour 2 of 72: 5 / 47999 windows flagged as calls
# Processing hour 3 of 72: 6 / 47999 windows flagged as calls
# Processing hour 4 of 72: 3 / 47999 windows flagged as calls
# Processing hour 5 of 72: 4 / 47999 windows flagged as calls
# Processing hour 6 of 72: 2 / 47999 windows flagged as calls
# Processing hour 7 of 72: 1 / 47999 windows flagged as calls
# Processing hour 8 of 72: 3 / 47999 windows flagged as calls
# Processing hour 9 of 72: 2 / 47999 windows flagged as calls
# Processing hour 10 of 72: 2 / 47999 windows flagged as calls
# Processing hour 11 of 72: 4 / 47999 windows flagged as calls
# Processing hour 12 of 72: 3 / 47999 windows flagged as calls
# Processing hour 13 of 72: 3 / 47999 windows flagged as calls
# Processing hour 14 of 72: 17 / 47999 windows flagged as calls
# Processing hour 15 of 72: 37 / 47999 windows flagged as calls
# Processing hour 16 of 72: 5 / 47999 windows flagged as calls
# Processing hour 17 of 72: 13 / 47999 windows flagged as calls
# Processing hour 18 of 72: 6 / 47999 windows flagged as calls
# Processing hour 19 of 72: 157 / 47999 windows flagged as calls
# Processing hour 20 of 72: 11 / 47999 windows flagged as calls
# Processing hour 21 of 72: 305 / 47999 windows flagged as calls
# Processing hour 22 of 72: 19 / 47999 windows flagged as calls
# Processing hour 23 of 72: 2 / 47999 windows flagged as calls
# Processing hour 24 of 72: 6 / 47999 windows flagged as calls
# Processing hour 25 of 72: 32 / 47999 windows flagged as calls
# Processing hour 26 of 72: 2 / 47999 windows flagged as calls
# Processing hour 27 of 72: 8 / 47999 windows flagged as calls
# Processing hour 28 of 72: 2 / 47999 windows flagged as calls
# Processing hour 29 of 72: 0 / 47999 windows flagged as calls
# Processing hour 30 of 72: 1 / 47999 windows flagged as calls
# Processing hour 31 of 72: 9 / 47999 windows flagged as calls
# Processing hour 32 of 72: 6 / 47999 windows flagged as calls
# Processing hour 33 of 72: 9 / 47999 windows flagged as calls
# Processing hour 34 of 72: 18 / 47999 windows flagged as calls
# Processing hour 35 of 72: 19 / 47999 windows flagged as calls
# Processing hour 36 of 72: 6 / 47999 windows flagged as calls
# Processing hour 37 of 72: 45 / 47999 windows flagged as calls
# Processing hour 38 of 72: 469 / 47999 windows flagged as calls
# Processing hour 39 of 72: 215 / 47999 windows flagged as calls
# Processing hour 40 of 72: 80 / 47999 windows flagged as calls
# Processing hour 41 of 72: 865 / 47999 windows flagged as calls
# Processing hour 42 of 72: 1000 / 47999 windows flagged as calls
# Processing hour 43 of 72: 4993 / 47999 windows flagged as calls
# Processing hour 44 of 72: 1979 / 47999 windows flagged as calls
# Processing hour 45 of 72: 1537 / 47999 windows flagged as calls
# Processing hour 46 of 72: 712 / 47999 windows flagged as calls
# Processing hour 47 of 72: 6207 / 47999 windows flagged as calls
# Processing hour 48 of 72: 317 / 47999 windows flagged as calls
# Processing hour 49 of 72: 170 / 47999 windows flagged as calls
# Processing hour 50 of 72: 181 / 47999 windows flagged as calls
# Processing hour 51 of 72: 199 / 47999 windows flagged as calls
# Processing hour 52 of 72: 172 / 47999 windows flagged as calls
# Processing hour 53 of 72: 179 / 47999 windows flagged as calls
# Processing hour 54 of 72: 195 / 47999 windows flagged as calls
# Processing hour 55 of 72: 238 / 47999 windows flagged as calls
# Processing hour 56 of 72: 218 / 47999 windows flagged as calls
# Processing hour 57 of 72: 278 / 47999 windows flagged as calls
# Processing hour 58 of 72: 329 / 47999 windows flagged as calls
# Processing hour 59 of 72: 316 / 47999 windows flagged as calls
# Processing hour 60 of 72: 447 / 47999 windows flagged as calls
# Processing hour 61 of 72: 353 / 47999 windows flagged as calls
# Processing hour 62 of 72: 480 / 47999 windows flagged as calls
# Processing hour 63 of 72: 325 / 47999 windows flagged as calls
# Processing hour 64 of 72: 269 / 47999 windows flagged as calls
# Processing hour 65 of 72: 695 / 47999 windows flagged as calls
# Processing hour 66 of 72: 619 / 47999 windows flagged as calls
# Processing hour 67 of 72: 466 / 47999 windows flagged as calls
# Processing hour 68 of 72: 266 / 47999 windows flagged as calls
# Processing hour 69 of 72: 485 / 47999 windows flagged as calls
# Processing hour 70 of 72: 578 / 47999 windows flagged as calls
# Processing hour 71 of 72: 903 / 47999 windows flagged as calls
# Processing hour 72 of 72: 123 / 47999 windows flagged as calls

# %% [markdown]
# Merge Consecutive detected windows

# %%
step = 0.075       # step_len in seconds (150ms window, 50% overlap -> 75ms step)
window_len = 0.15  # window length in seconds
tol = 1e-6         # floating point tolerance

combined_calls = []  # list of (start_time, end_time, label)

if len(all_detected_t) > 0:
    run_start = all_detected_t[0]
    run_end   = all_detected_t[0]
    run_label = all_detected_labels[0]

    for t, label in zip(all_detected_t[1:], all_detected_labels[1:]):
        gap = t - run_end
        is_consecutive = np.isclose(gap, step, atol=tol)

        if is_consecutive and label == run_label:
            # extend the current run
            run_end = t
        else:
            # close out the current run, start a new one
            combined_calls.append((run_start, run_end + window_len, run_label))
            run_start = t
            run_end = t
            run_label = label

    # don't forget to flush the last run after the loop ends
    combined_calls.append((run_start, run_end + window_len, run_label))

print(f"Merged {len(all_detected_t)} raw window detections into {len(combined_calls)} calls")
# Out:
# Merged 27671 raw window detections into 11783 calls

# %% [markdown]
# PR curve / Ground truthing

# %%
ground_truth = load_raven_selection_table(DATA_22 / "2023-04-22T17-13-01_000_00070.txt")

# %%
precision, recall, thresholds = compute_pr_curve(
    all_times_all, all_scores, all_labels_all, ground_truth,
    step=step, window_len=window_len, n_thresholds=50, require_label_match=False
)
# Out:
# 0.06955405258980672
# 0.07914574009099028
# 0.08873742759217382
# 0.09832911509335737
# 0.10792080259454093
# 0.11751249009572447
# 0.127104177596908
# 0.13669586509809156
# 0.14628755259927512
# 0.15587924010045867
# 0.16547092760164223
# 0.17506261510282578
# 0.18465430260400933
# 0.19424599010519286
# 0.2038376776063764
# 0.21342936510755994
# 0.2230210526087435
# 0.23261274010992705
# 0.2422044276111106
# 0.25179611511229416
# 0.2613878026134777
# 0.27097949011466127
# 0.2805711776158448
# 0.2901628651170284
# 0.29975455261821193
# 0.30934624011939543
# 0.318937927620579
# 0.32852961512176254
# 0.3381213026229461
# 0.34771299012412965
# 0.3573046776253132
# 0.36689636512649676
# 0.3764880526276803
# 0.38607974012886387
# 0.3956714276300474
# 0.405263115131231
# 0.41485480263241453
# 0.4244464901335981
# 0.4340381776347816
# 0.44362986513596514
# 0.4532215526371487
# 0.46281324013833225
# 0.4724049276395158
# 0.48199661514069936
# 0.4915883026418829
# 0.5011799901430665
# 0.51077167764425
# 0.5203633651454336
# 0.5299550526466171
# 0.5395467401478007

# %%
ap = compute_average_precision(precision, recall)
print(f"Average Precision: {ap:.4f}")

idx = np.argmin(np.abs(thresholds - mt_threshold))
print(f"At your chosen mt_threshold: precision={precision[idx]:.3f}, recall={recall[idx]:.3f}")

tp, fp, fn = match_detections(combined_calls, ground_truth, require_label_match=False)
precision_point = tp / (tp + fp) if (tp + fp) > 0 else 1.0
recall_point = tp / (tp + fn) if (tp + fn) > 0 else 0.0
print(f"combined_calls: precision={precision_point:.3f}, recall={recall_point:.3f}")
# Out:
# Average Precision: 0.6649
# At your chosen mt_threshold: precision=0.223, recall=0.889
# combined_calls: precision=0.137, recall=0.893

# %%
plot_pr_curve(precision, recall, ap=ap, marked_point=(precision_point, recall_point))
