# %%
from pathlib import Path
import numpy as np
from feature import make_mfcc_extractor
from test_vectorized import (
    merge_consecutive_detections, run_detection_pipeline_new,
    load_all_template_features_new, load_all_thresholds_new, plot_pr_curve, load_raven_selection_table, compute_average_precision, match_detections,
    plot_detection_spectrograms, get_exclusion_intervals, compute_pr_curve_alpha
)


DATA_22 = Path(r"C:\Users\HP\Desktop\Skripsie data\22")
DATA_29 = Path(r"C:\Users\HP\Desktop\Skripsie data\29")
RESULTS_29 = DATA_29 / "template_selections"

RESULTS = Path(r"C:\Users\HP\Desktop\Skripsie data\Results")
THRESHOLDS = RESULTS / "Thresholds"

file_name = "10_Templates"
n_temps = 10
extractor = make_mfcc_extractor()

# %%
st_feats, mt_feats, bt_feats = load_all_template_features_new(
    results_dir=RESULTS_29,
    file_label="20230429_Templates",
    recording_label="20230429_102841",
    extractor=extractor,
    n_templates=n_temps,
    fs_new=1000,
)

# %% [markdown]
# Load thresholds

# %%
st_threshold, mt_threshold, bt_threshold = load_all_thresholds_new(
    results_dir=THRESHOLDS,
    file_label=file_name,          # matches what your calibration loop saved
    extractor=extractor,
)

print(f"Single Tone Threshold: {st_threshold}")
print(f"Multi Tone Threshold: {mt_threshold}")
print(f"Burst Tonal Threshold: {bt_threshold}")
# Out:
# Single Tone Threshold: 8.965872813373219
# Multi Tone Threshold: 9.110623928383788
# Burst Tonal Threshold: 9.90564697399278

# %% [markdown]
# Load 72 hour audio in 1 hour segments

# %%
ground_truth = load_raven_selection_table(DATA_22 / "2023-04-22T17-13-01_000_00070.txt")
td_intervals = get_exclusion_intervals(ground_truth, exclude_labels=("td",), pad=0.1)

all_detected_t, all_detected_labels, all_scores, all_labels_all, all_times_all, all_kth = run_detection_pipeline_new(
    audio_file=DATA_22 / "20230422_171301.wav",
    n_hours=72,
    st_feats=st_feats, mt_feats=mt_feats, bt_feats=bt_feats,
    st_threshold=st_threshold, mt_threshold=mt_threshold, bt_threshold=bt_threshold,
    exclude_intervals=td_intervals,
    extractor=extractor,
)
# Out:
# Processing hour 1 of 72: 1 / 47999 windows flagged as calls
# Processing hour 2 of 72: 0 / 47999 windows flagged as calls
# Processing hour 3 of 72: 0 / 47999 windows flagged as calls
# Processing hour 4 of 72: 0 / 47999 windows flagged as calls
# Processing hour 5 of 72: 0 / 47999 windows flagged as calls
# Processing hour 6 of 72: 0 / 47999 windows flagged as calls
# Processing hour 7 of 72: 0 / 47999 windows flagged as calls
# Processing hour 8 of 72: 0 / 47999 windows flagged as calls
# Processing hour 9 of 72: 0 / 47999 windows flagged as calls
# Processing hour 10 of 72: 0 / 47999 windows flagged as calls
# Processing hour 11 of 72: 0 / 47999 windows flagged as calls
# Processing hour 12 of 72: 0 / 47999 windows flagged as calls
# Processing hour 13 of 72: 0 / 47999 windows flagged as calls
# Processing hour 14 of 72: 0 / 47999 windows flagged as calls
# Processing hour 15 of 72: 1 / 47999 windows flagged as calls
# Processing hour 16 of 72: 0 / 47999 windows flagged as calls
# Processing hour 17 of 72: 1 / 47999 windows flagged as calls
# Processing hour 18 of 72: 0 / 47999 windows flagged as calls
# Processing hour 19 of 72: 4 / 47999 windows flagged as calls
# Processing hour 20 of 72: 0 / 47999 windows flagged as calls
# Processing hour 21 of 72: 3 / 47999 windows flagged as calls
# Processing hour 22 of 72: 0 / 47999 windows flagged as calls
# Processing hour 23 of 72: 0 / 47999 windows flagged as calls
# Processing hour 24 of 72: 0 / 47999 windows flagged as calls
# Processing hour 25 of 72: 1 / 47999 windows flagged as calls
# Processing hour 26 of 72: 0 / 47999 windows flagged as calls
# Processing hour 27 of 72: 2 / 47999 windows flagged as calls
# Processing hour 28 of 72: 0 / 47999 windows flagged as calls
# Processing hour 29 of 72: 0 / 47999 windows flagged as calls
# Processing hour 30 of 72: 0 / 47999 windows flagged as calls
# Processing hour 31 of 72: 1 / 47999 windows flagged as calls
# Processing hour 32 of 72: 1 / 47999 windows flagged as calls
# Processing hour 33 of 72: 0 / 47999 windows flagged as calls
# Processing hour 34 of 72: 0 / 47999 windows flagged as calls
# Processing hour 35 of 72: 0 / 47999 windows flagged as calls
# Processing hour 36 of 72: 0 / 47999 windows flagged as calls
# Processing hour 37 of 72: 4 / 47999 windows flagged as calls
# Processing hour 38 of 72: 32 / 47999 windows flagged as calls
# Processing hour 39 of 72: 6 / 47999 windows flagged as calls
# Processing hour 40 of 72: 3 / 47999 windows flagged as calls
# Processing hour 41 of 72: 101 / 47999 windows flagged as calls
# Processing hour 42 of 72: 148 / 47999 windows flagged as calls
# Processing hour 43 of 72: 686 / 47999 windows flagged as calls
# Processing hour 44 of 72: 140 / 47999 windows flagged as calls
# Processing hour 45 of 72: 93 / 47999 windows flagged as calls
# Processing hour 46 of 72: 41 / 47999 windows flagged as calls
# Processing hour 47 of 72: 1019 / 47999 windows flagged as calls
# Processing hour 48 of 72: 20 / 47999 windows flagged as calls
# Processing hour 49 of 72: 5 / 47999 windows flagged as calls
# Processing hour 50 of 72: 5 / 47999 windows flagged as calls
# Processing hour 51 of 72: 28 / 47999 windows flagged as calls
# Processing hour 52 of 72: 35 / 47999 windows flagged as calls
# Processing hour 53 of 72: 59 / 47999 windows flagged as calls
# Processing hour 54 of 72: 158 / 47999 windows flagged as calls
# Processing hour 55 of 72: 373 / 47999 windows flagged as calls
# Processing hour 56 of 72: 329 / 47590 windows flagged as calls
# Processing hour 57 of 72: 589 / 46177 windows flagged as calls
# Processing hour 58 of 72: 607 / 47999 windows flagged as calls
# Processing hour 59 of 72: 553 / 47999 windows flagged as calls
# Processing hour 60 of 72: 476 / 47999 windows flagged as calls
# Processing hour 61 of 72: 657 / 47999 windows flagged as calls
# Processing hour 62 of 72: 531 / 47999 windows flagged as calls
# Processing hour 63 of 72: 648 / 47999 windows flagged as calls
# Processing hour 64 of 72: 399 / 47999 windows flagged as calls
# Processing hour 65 of 72: 477 / 47999 windows flagged as calls
# Processing hour 66 of 72: 400 / 47999 windows flagged as calls
# Processing hour 67 of 72: 101 / 47999 windows flagged as calls
# Processing hour 68 of 72: 89 / 47999 windows flagged as calls
# Processing hour 69 of 72: 86 / 47999 windows flagged as calls
# Processing hour 70 of 72: 85 / 47999 windows flagged as calls
# Processing hour 71 of 72: 126 / 47999 windows flagged as calls
# Processing hour 72 of 72: 37 / 47999 windows flagged as calls

# %% [markdown]
# Merge Consecutive detected windows

# %%
# 1. settings and ground truth first
MIN_WINDOWS = 4
MAX_WINDOWS = 14
merge_kw = dict(max_gap_windows=1, min_windows=MIN_WINDOWS, max_windows=MAX_WINDOWS)

ground_truth = load_raven_selection_table(DATA_22 / "2023-04-22T17-13-01_000_00070.txt")
ground_truth_eval = [g for g in ground_truth if g["label"] not in ("td",)]

# 2. deployed operating point (unchanged)
calls = merge_consecutive_detections(all_detected_t, all_detected_labels,
                                     step=0.075, window_len=0.15, **merge_kw)
tp, fp, fn, false_positive_detections, false_negative_gts = match_detections(
    calls, ground_truth_eval, require_label_match=False)
print(f"deployed: calls={len(calls)}  P={tp/(tp+fp):.3f}  R={tp/(tp+fn):.3f}")

# 3. alpha curve, using the same merge_kw
thr = (st_threshold, mt_threshold, bt_threshold)
best_ratio = (all_kth / np.array(thr)).min(axis=1)
print("sanity:", (best_ratio < 1).sum(), len(all_detected_t))   # should match

frac = len(all_detected_t) / len(all_times_all)
qs = np.quantile(best_ratio[np.isfinite(best_ratio)],
                 np.geomspace(1e-4, min(0.5, 5 * frac), 60))
alphas = np.unique(np.append(qs, [1.0, 2.0, 3.0]))

precision, recall, used, _ = compute_pr_curve_alpha(
    all_times_all, all_kth, thr, ground_truth_eval,
    step=0.075, window_len=0.15, alphas=alphas, **merge_kw)

p1, r1, _, _ = compute_pr_curve_alpha(
    all_times_all, all_kth, thr, ground_truth_eval,
    step=0.075, window_len=0.15, alphas=[1.0], **merge_kw)
print(f"alpha=1: P={p1[0]:.3f}  R={r1[0]:.3f}   (should be close to the deployed line above)")

ap = compute_average_precision(precision, recall)
plot_pr_curve(precision, recall, ap=ap, marked_point=(p1[0], r1[0]))
# Out:
# deployed: calls=385  P=0.281  R=0.066
# sanity: 9161 9161
# alpha=1: P=0.281  R=0.066   (should be close to the deployed line above)

# %%
#combined_calls = merge_consecutive_detections(all_detected_t, all_detected_labels, step=0.075, window_len=0.15)

#print(f"Merged {len(all_detected_t)} raw window detections into {len(combined_calls)} calls")

# %% [markdown]
# PR curve / Ground truthing

# %%
plot_detection_spectrograms(
    false_positive_detections,
    DATA_22 / "20230422_171301.wav",
    fs_new=1000,
    n_examples=12,
    title_prefix="FP",
    extractor=extractor,
)

fn_as_tuples = [(g["start"], g["end"], g["label"]) for g in false_negative_gts]
plot_detection_spectrograms(
    fn_as_tuples,
    DATA_22 / "20230422_171301.wav",
    fs_new=1000,
    n_examples=12,
    title_prefix="FN",
    extractor=extractor,
)
