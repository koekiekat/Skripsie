# %%
from pathlib import Path
import numpy as np
from feature import make_stft_extractor
from test_vectorized import (
    merge_consecutive_detections, run_detection_pipeline_new,
    load_all_template_features_new, load_all_thresholds_new,
    read_audio_chunk, plot_pr_curve, load_raven_selection_table,
    compute_pr_curve, compute_average_precision, match_detections,
    plot_detection_spectrograms, get_exclusion_intervals, get_exclusion_mask, compute_pr_curve_alpha
)


DATA_22 = Path(r"C:\Users\HP\Desktop\Skripsie data\22")
DATA_29 = Path(r"C:\Users\HP\Desktop\Skripsie data\29")
RESULTS_29 = DATA_29 / "template_selections"

RESULTS = Path(r"C:\Users\HP\Desktop\Skripsie data\Results")
THRESHOLDS = RESULTS / "Thresholds"

file_name = "10_Templates"
n_temps = 10
extractor = make_stft_extractor()

# %%
st_feats, mt_feats, bt_feats = load_all_template_features_new(
    results_dir=RESULTS_29,
    file_label="20230429_Templates",
    recording_label="20230429_102841",
    extractor=extractor,
    n_templates=n_temps,
    fs_new=1000,
)

# %% [markdown]
# Load thresholds

# %%
st_threshold, mt_threshold, bt_threshold = load_all_thresholds_new(
    results_dir=THRESHOLDS,
    file_label= file_name,          # matches what your calibration loop saved
    extractor=extractor,
)

print(f"Single Tone Threshold: {st_threshold}")
print(f"Multi Tone Threshold: {mt_threshold}")
print(f"Burst Tonal Threshold: {bt_threshold}")
# Out:
# Single Tone Threshold: 0.13991060804627278
# Multi Tone Threshold: 0.13775216233954574
# Burst Tonal Threshold: 0.14513978690354087

# %% [markdown]
# Load 72 hour audio in 1 hour segments

# %%
ground_truth = load_raven_selection_table(DATA_22 / "2023-04-22T17-13-01_000_00070.txt")
td_intervals = get_exclusion_intervals(ground_truth, exclude_labels=("td",), pad=0.1)

all_detected_t, all_detected_labels, all_scores, all_labels_all, all_times_all, all_kth = run_detection_pipeline_new(
    audio_file=DATA_22 / "20230422_171301.wav",
    n_hours=72,
    st_feats=st_feats, mt_feats=mt_feats, bt_feats=bt_feats,
    st_threshold=st_threshold, mt_threshold=mt_threshold, bt_threshold=bt_threshold,
    exclude_intervals=td_intervals,
    extractor=extractor,
)
# Out:
# Processing hour 1 of 72: 21 / 47999 windows flagged as calls
# Processing hour 2 of 72: 3 / 47999 windows flagged as calls
# Processing hour 3 of 72: 3 / 47999 windows flagged as calls
# Processing hour 4 of 72: 0 / 47999 windows flagged as calls
# Processing hour 5 of 72: 0 / 47999 windows flagged as calls
# Processing hour 6 of 72: 2 / 47999 windows flagged as calls
# Processing hour 7 of 72: 0 / 47999 windows flagged as calls
# Processing hour 8 of 72: 0 / 47999 windows flagged as calls
# Processing hour 9 of 72: 0 / 47999 windows flagged as calls
# Processing hour 10 of 72: 2 / 47999 windows flagged as calls
# Processing hour 11 of 72: 2 / 47999 windows flagged as calls
# Processing hour 12 of 72: 0 / 47999 windows flagged as calls
# Processing hour 13 of 72: 0 / 47999 windows flagged as calls
# Processing hour 14 of 72: 14 / 47999 windows flagged as calls
# Processing hour 15 of 72: 20 / 47999 windows flagged as calls
# Processing hour 16 of 72: 2 / 47999 windows flagged as calls
# Processing hour 17 of 72: 8 / 47999 windows flagged as calls
# Processing hour 18 of 72: 1 / 47999 windows flagged as calls
# Processing hour 19 of 72: 98 / 47999 windows flagged as calls
# Processing hour 20 of 72: 5 / 47999 windows flagged as calls
# Processing hour 21 of 72: 193 / 47999 windows flagged as calls
# Processing hour 22 of 72: 14 / 47999 windows flagged as calls
# Processing hour 23 of 72: 1 / 47999 windows flagged as calls
# Processing hour 24 of 72: 2 / 47999 windows flagged as calls
# Processing hour 25 of 72: 24 / 47999 windows flagged as calls
# Processing hour 26 of 72: 0 / 47999 windows flagged as calls
# Processing hour 27 of 72: 3 / 47999 windows flagged as calls
# Processing hour 28 of 72: 1 / 47999 windows flagged as calls
# Processing hour 29 of 72: 0 / 47999 windows flagged as calls
# Processing hour 30 of 72: 0 / 47999 windows flagged as calls
# Processing hour 31 of 72: 5 / 47999 windows flagged as calls
# Processing hour 32 of 72: 2 / 47999 windows flagged as calls
# Processing hour 33 of 72: 0 / 47999 windows flagged as calls
# Processing hour 34 of 72: 0 / 47999 windows flagged as calls
# Processing hour 35 of 72: 0 / 47999 windows flagged as calls
# Processing hour 36 of 72: 4 / 47999 windows flagged as calls
# Processing hour 37 of 72: 18 / 47999 windows flagged as calls
# Processing hour 38 of 72: 303 / 47999 windows flagged as calls
# Processing hour 39 of 72: 72 / 47999 windows flagged as calls
# Processing hour 40 of 72: 23 / 47999 windows flagged as calls
# Processing hour 41 of 72: 619 / 47999 windows flagged as calls
# Processing hour 42 of 72: 753 / 47999 windows flagged as calls
# Processing hour 43 of 72: 3986 / 47999 windows flagged as calls
# Processing hour 44 of 72: 1279 / 47999 windows flagged as calls
# Processing hour 45 of 72: 1013 / 47999 windows flagged as calls
# Processing hour 46 of 72: 446 / 47999 windows flagged as calls
# Processing hour 47 of 72: 5211 / 47999 windows flagged as calls
# Processing hour 48 of 72: 163 / 47999 windows flagged as calls
# Processing hour 49 of 72: 62 / 47999 windows flagged as calls
# Processing hour 50 of 72: 50 / 47999 windows flagged as calls
# Processing hour 51 of 72: 57 / 47999 windows flagged as calls
# Processing hour 52 of 72: 52 / 47999 windows flagged as calls
# Processing hour 53 of 72: 56 / 47999 windows flagged as calls
# Processing hour 54 of 72: 60 / 47999 windows flagged as calls
# Processing hour 55 of 72: 83 / 47999 windows flagged as calls
# Processing hour 56 of 72: 77 / 47590 windows flagged as calls
# Processing hour 57 of 72: 102 / 46177 windows flagged as calls
# Processing hour 58 of 72: 129 / 47999 windows flagged as calls
# Processing hour 59 of 72: 101 / 47999 windows flagged as calls
# Processing hour 60 of 72: 232 / 47999 windows flagged as calls
# Processing hour 61 of 72: 142 / 47999 windows flagged as calls
# Processing hour 62 of 72: 226 / 47999 windows flagged as calls
# Processing hour 63 of 72: 116 / 47999 windows flagged as calls
# Processing hour 64 of 72: 82 / 47999 windows flagged as calls
# Processing hour 65 of 72: 382 / 47999 windows flagged as calls
# Processing hour 66 of 72: 336 / 47999 windows flagged as calls
# Processing hour 67 of 72: 236 / 47999 windows flagged as calls
# Processing hour 68 of 72: 92 / 47999 windows flagged as calls
# Processing hour 69 of 72: 229 / 47999 windows flagged as calls
# Processing hour 70 of 72: 302 / 47999 windows flagged as calls
# Processing hour 71 of 72: 609 / 47999 windows flagged as calls
# Processing hour 72 of 72: 28 / 47999 windows flagged as calls

# %%
# 1. settings and ground truth first
MIN_WINDOWS = 4
MAX_WINDOWS = 14
merge_kw = dict(max_gap_windows=1, min_windows=MIN_WINDOWS, max_windows=MAX_WINDOWS)

ground_truth = load_raven_selection_table(DATA_22 / "2023-04-22T17-13-01_000_00070.txt")
ground_truth_eval = [g for g in ground_truth if g["label"] not in ("td",)]

# 2. deployed operating point (unchanged)
calls = merge_consecutive_detections(all_detected_t, all_detected_labels,
                                     step=0.075, window_len=0.15, **merge_kw)
tp, fp, fn, false_positive_detections, false_negative_gts = match_detections(
    calls, ground_truth_eval, require_label_match=False)
print(f"deployed: calls={len(calls)}  P={tp/(tp+fp):.3f}  R={tp/(tp+fn):.3f}")

# 3. alpha curve, using the same merge_kw
thr = (st_threshold, mt_threshold, bt_threshold)
best_ratio = (all_kth / np.array(thr)).min(axis=1)
print("sanity:", (best_ratio < 1).sum(), len(all_detected_t))   # should match

frac = len(all_detected_t) / len(all_times_all)
qs = np.quantile(best_ratio[np.isfinite(best_ratio)],
                 np.geomspace(1e-4, min(0.5, 5 * frac), 60))
alphas = np.unique(np.append(qs, [1.0, 2.0, 3.0]))

precision, recall, used, _ = compute_pr_curve_alpha(
    all_times_all, all_kth, thr, ground_truth_eval,
    step=0.075, window_len=0.15, alphas=alphas, **merge_kw)

p1, r1, _, _ = compute_pr_curve_alpha(
    all_times_all, all_kth, thr, ground_truth_eval,
    step=0.075, window_len=0.15, alphas=[1.0], **merge_kw)
print(f"alpha=1: P={p1[0]:.3f}  R={r1[0]:.3f}   (should be close to the deployed line above)")

ap = compute_average_precision(precision, recall)
plot_pr_curve(precision, recall, ap=ap, marked_point=(p1[0], r1[0]))
# Out:
# deployed: calls=2030  P=0.712  R=0.882
# sanity: 18157 18157
# alpha=1: P=0.712  R=0.882   (should be close to the deployed line above)

# %% [markdown]
# Merge Consecutive detected windows

# %%
combined_calls = merge_consecutive_detections(all_detected_t, all_detected_labels, step=0.075, window_len=0.15)

print(f"Merged {len(all_detected_t)} raw window detections into {len(combined_calls)} calls")
# Out:
# Merged 18157 raw window detections into 5962 calls

# %% [markdown]
# PR curve / Ground truthing

# %%
# plot a random sample of false positives
plot_detection_spectrograms(
    false_positive_detections,
    DATA_22 / "20230422_171301.wav",
    fs_new=1000,
    n_examples=12,
    title_prefix="FP"
)

# you can also inspect false negatives (missed calls) the same way
fn_as_tuples = [(g["start"], g["end"], g["label"]) for g in false_negative_gts]
plot_detection_spectrograms(
    fn_as_tuples,
    DATA_22 / "20230422_171301.wav",
    fs_new=1000,
    n_examples=12,
    title_prefix="FN"
)
